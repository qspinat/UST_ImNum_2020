# %%
from google.colab import drive
drive.mount('/content/drive/')
 
import sys
sys.path.append('/content/drive/')

# %cd drive/MyDrive/PytorchWCT/
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/MyDrive/PytorchWCT

# %%
# !pip install torchfile

# %%
import torch

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
import matplotlib.pyplot as plt
from new_func import *

content = "images/style/mona.jpeg"
style = "images/style/vangogh.jpg"
color="content"
resize_content=1080
resize_style=720
alpha = [0.6,0.8,0.9,0.9,1.]


image1 = easy_transfert(content,style,resize_content=resize_content,resize_style=resize_style,color=color,alpha=alpha)
image2 = easy_transfert(content,style,resize_content=resize_content,resize_style=resize_style,color="style",alpha=alpha)

plt.figure(figsize = (15,15))
plt.imshow(image1)
plt.title("content colors")
plt.axis("off")

plt.figure(figsize = (15,15))
plt.imshow(image2)
plt.legend("style colors")
plt.axis("off")
# Out:
# /content/drive/My Drive/PytorchWCT/new_func.py:126: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   cImg = Variable(content[None,:],volatile=True).to(device)
# /content/drive/My Drive/PytorchWCT/new_func.py:127: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   sImg = Variable(style[None,:],volatile=True).to(device)
# Elapsed time is: 6.973588
# Averaged time is 6.973588
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Elapsed time is: 6.588337
# Averaged time is 6.588337
# (-0.5, 719.5, 1071.5, -0.5)
